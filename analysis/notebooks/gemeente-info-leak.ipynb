# %%
import sqlite3
import logging
import pandas as pd
from urllib.parse import urlparse
from tld import get_tld, get_fld

# %%
logger = logging.getLogger('analysis')
logger.setLevel('INFO')

# %%
# Specify your local path to the sqlite db containing crawl data
SQLITE_LOCAL_PATH = '/home/duud/repos/gemeente-social/data/crawl-data-copy.sqlite'

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect(SQLITE_LOCAL_PATH)

# %%
cursor = con.cursor()
# Parse javascript table from SQLite
javascript = pd.read_sql_query("SELECT * from javascript", con)
# Parse SITE_VISITS table from SQLite
site_visits = pd.read_sql_query("SELECT * from site_visits", con)

# %%
#site_visits = pd.read_sql_query("SELECT * from site_visits", con)
def parse_tld_url(url):
    return get_fld(url, fail_silently=True)

site_visits['tld_url'] = site_visits['site_url'].apply(parse_tld_url)
print(site_visits['tld_url'].value_counts().head(20))

import pdb; pdb.set_trace()

# verify that result of SQL query is stored in the dataframe
site_visits.head()
javascript.head()

con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: no such table: javascript
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-11-ca7cda4a2898> in <module>
#       1 #site_visits = pd.read_sql_query("SELECT * from site_visits", con)
# ----> 2 javascript = pd.read_sql_query("SELECT * from javascript", con)
#       3
#       4 def parse_tld_url(url):
#       5     return get_fld(url, fail_silently=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1466
#    1467         args = _convert_params(sql, params)
# -> 1468         cursor = self.execute(*args)
#    1469         columns = [col_desc[0] for col_desc in cursor.description]
#    1470
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1443                 "Execution failed on sql '{sql}': {exc}".format(
#    1444                     sql=args[0], exc=exc))
# -> 1445             raise_with_traceback(ex)
#    1446
#    1447     @staticmethod
#
# ~/.local/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     418         if traceback == Ellipsis:
#     419             _, _, traceback = sys.exc_info()
# --> 420         raise exc.with_traceback(traceback)
#     421 else:
#     422     # this version of raise is a syntax error in Python 3
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1429                 cur.execute(*args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#    1433         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT * from javascript': no such table: javascript

# %%
# Out:
#    id  incognito  crawl_id  visit_id                extension_session_uuid  \
# 0   1          0         1         1  454110b6-8f86-455a-aea8-cd3d3280a6e1
# 1   2          0         1         1  454110b6-8f86-455a-aea8-cd3d3280a6e1
# 2   3          0         7         7  1764a68a-59dc-4c9b-9ae1-d20b0148ccd8
# 3   4          0         7         7  1764a68a-59dc-4c9b-9ae1-d20b0148ccd8
# 4   5          0         6         6  1294dd89-3e69-4ede-8fd2-b13787372577
# 5   6          0         8         8  113d2ed6-5d97-45fc-a82d-5420f6a53a37
# 6   7          0         8         8  113d2ed6-5d97-45fc-a82d-5420f6a53a37
# 7   8          0         8         8  113d2ed6-5d97-45fc-a82d-5420f6a53a37
# 8   9          0         8         8  113d2ed6-5d97-45fc-a82d-5420f6a53a37
# 9  10          0         8         8  113d2ed6-5d97-45fc-a82d-5420f6a53a37
#
#    event_ordinal  page_scoped_event_ordinal  window_id  tab_id  frame_id  ...  \
# 0             31                          0          3       1         0  ...
# 1             32                          1          3       1         0  ...
# 2             55                          0          3       1         0  ...
# 3             56                          1          3       1         0  ...
# 4             97                          0          3       1         0  ...
# 5             45                          0          3       1         0  ...
# 6             46                          1          3       1         0  ...
# 7             47                          2          3       1         0  ...
# 8             48                          3          3       1         0  ...
# 9             49                          4          3       1         0  ...
#
#                         func_name script_loc_eval  \
# 0
# 1
# 2              Prototype.Browser<
# 3
# 4
# 5  OpenLayers.Util.getBrowserName
# 6  OpenLayers.Util.getBrowserName
# 7  OpenLayers.Util.getBrowserName
# 8  OpenLayers.Util.getBrowserName
# 9
#
#                                         document_url  \
# 0  https://dloket.groningen.nl/loket/burger/mijn_...
# 1  https://dloket.groningen.nl/loket/burger/mijn_...
# 2             https://www.aaenhunze.nl/Mijn_gemeente
# 3             https://www.aaenhunze.nl/Mijn_gemeente
# 4                     https://gemeente.groningen.nl/
# 5           https://www.drenthe.wegwerkmeldingen.nl/
# 6           https://www.drenthe.wegwerkmeldingen.nl/
# 7           https://www.drenthe.wegwerkmeldingen.nl/
# 8           https://www.drenthe.wegwerkmeldingen.nl/
# 9           https://www.drenthe.wegwerkmeldingen.nl/
#
#                                        top_level_url  \
# 0  https://dloket.groningen.nl/loket/burger/mijn_...
# 1  https://dloket.groningen.nl/loket/burger/mijn_...
# 2             https://www.aaenhunze.nl/Mijn_gemeente
# 3             https://www.aaenhunze.nl/Mijn_gemeente
# 4                     https://gemeente.groningen.nl/
# 5           https://www.drenthe.wegwerkmeldingen.nl/
# 6           https://www.drenthe.wegwerkmeldingen.nl/
# 7           https://www.drenthe.wegwerkmeldingen.nl/
# 8           https://www.drenthe.wegwerkmeldingen.nl/
# 9           https://www.drenthe.wegwerkmeldingen.nl/
#
#                                           call_stack  \
# 0
# 1  @https://dloket.groningen.nl/loket/sites/defau...
# 2
# 3
# 4  @https://gemeente.groningen.nl/misc/drupal.js?...
# 5
# 6
# 7
# 8
# 9
#
#                        symbol operation  \
# 0  window.navigator.userAgent       get
# 1      window.document.cookie       set
# 2  window.navigator.userAgent       get
# 3  window.navigator.userAgent       get
# 4      window.document.cookie       set
# 5  window.navigator.userAgent       get
# 6  window.navigator.userAgent       get
# 7  window.navigator.userAgent       get
# 8  window.navigator.userAgent       get
# 9  window.navigator.userAgent       get
#
#                                                value arguments  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 1                                   has_js=1; path=/      None
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 4                                   has_js=1; path=/      None
# 5  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 6  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 7  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 8  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
# 9  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      None
#
#                  time_stamp
# 0  2019-05-14T19:49:29.974Z
# 1  2019-05-14T19:49:30.299Z
# 2  2019-05-14T19:49:29.841Z
# 3  2019-05-14T19:49:30.155Z
# 4  2019-05-14T19:49:30.548Z
# 5  2019-05-14T19:49:32.159Z
# 6  2019-05-14T19:49:32.367Z
# 7  2019-05-14T19:49:32.369Z
# 8  2019-05-14T19:49:32.370Z
# 9  2019-05-14T19:49:32.372Z
#
# [10 rows x 23 columns]
