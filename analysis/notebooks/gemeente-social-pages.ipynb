# %%
import sqlite3
import logging
import pandas as pd
from urllib.parse import urlparse
from tld import get_tld, get_fld

# %%
logger = logging.getLogger('analysis')
logger.setLevel('INFO')

# %%
# Specify your local path to the sqlite db containing crawl data
SQLITE_LOCAL_PATH = '/home/berra/Documents/Mercator/gemeente-social/data/crawl-data-copy.sqlite'
# Specify the list for scoial media FLDs that we are interested in observing
SM_FLDS = ['facebook', 'instagram', 'linkedin', 'google', 'youtube', 'twitter']
#, 'whatsapp', 'snapchat', 'amazon', 'reddit']

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect(SQLITE_LOCAL_PATH)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-9278cb4bf649> in <module>()
#       1 # Read sqlite query results into a pandas DataFrame
# ----> 2 con = sqlite3.connect(SQLITE_LOCAL_PATH)
#
# OperationalError: unable to open database file

# %%
cursor = con.cursor()
# Parse javascript table from SQLite
javascript = pd.read_sql_query("SELECT * from javascript", con)
# Parse SITE_VISITS table from SQLite
site_visits = pd.read_sql_query("SELECT * from site_visits", con)

# %%
# Helper function to get TLD+1 level of crawled link.
def parse_tld_url(url):
    return get_fld(url, fail_silently=True)

# Helper function to match social media names in url FLDs
def sm_match(url, sm_name):
    if url is not None:
        return sm_name in url
    else:
        return None

# %%
# Extract the First level domain for page links at the top level;
# pages linked to via a hyperlink from the first visible page when visiting a gemeente website
site_visits['tld_url'] = site_visits['site_url'].apply(parse_tld_url)

# Extract the top level domain from the keyed gemeente website
site_visits['tld_parent'] = site_visits['parent_url'].apply(parse_tld_url)

# Create a boolean column for each social media site fo interest.
for i in SM_FLDS:
    site_visits[('is_' + i)] = site_visits['tld_url'].apply(sm_match, args=(i,))
    
# Return social media aggregates per gemeente per social media platform.
social_media_pressence = site_visits[['parent_url']+ [('is_' + i) for i in SM_FLDS]]\
    .groupby(['parent_url']).agg(['sum'])\
    .applymap(lambda x: True if x >= 1 else False)
social_media_pressence.head()
# Out:
#                               is_facebook is_instagram is_linkedin is_google  \
#                                       sum          sum         sum       sum
# parent_url
# http://gemeente.groningen.nl         True         True       False     False
# http://www.aaenhunze.nl              True        False       False     False
# http://www.aalsmeer.nl               True        False        True     False
# http://www.aalten.nl                 True        False        True     False
# http://www.achtkarspelen.nl          True        False       False     False
#
#                               is_youtube is_twitter
#                                      sum        sum
# parent_url
# http://gemeente.groningen.nl       False       True
# http://www.aaenhunze.nl             True       True
# http://www.aalsmeer.nl              True       True
# http://www.aalten.nl               False       True
# http://www.achtkarspelen.nl        False       True

# %%
social_media_pressence.sum()/len(site_visits['parent_url'].unique())*100
#num_gemeente = len(site_visits['parent_url'].unique())
#javascript.head()
#con.close()
# Out:
# is_facebook   sum    79.761905
# is_instagram  sum    35.714286
# is_linkedin   sum    25.595238
# is_google     sum     6.547619
# is_youtube    sum    29.761905
# is_twitter    sum    82.142857
# dtype: float64

# %%
counted_total = round(\
    social_media_pressence.sum(axis=1).apply(lambda p: p > 0).sum()\
                      /len(site_visits['parent_url'].unique()),  3) * 100
print(str(counted_total) + '% of gemeente websites link directly to at least one of the 6 most popular social network pages on their first page.')
# Out:
# 83.3% of gemeente websites link directly to at least one of the 6 most popular social network pages on their first page.

# %%
# Display the full, untruncated social media presence data frame.
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', -1)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')
    
print_full(social_media_pressence)
# Out:
#                                       is_facebook is_instagram is_linkedin is_google is_youtube is_twitter
#                                               sum          sum         sum       sum        sum        sum
# parent_url
# http://gemeente.groningen.nl           True        True         False       False     False      True
# http://www.aaenhunze.nl                True        False        False       False     True       True
# http://www.aalsmeer.nl                 True        False        True        False     True       True
# http://www.aalten.nl                   True        False        True        False     False      True
# http://www.achtkarspelen.nl            True        False        False       False     False      True
# http://www.alblasserdam.nl             False       False        False       False     False      False
# http://www.alkmaar.nl                  True        False        False       False     True       True
# http://www.almelo.nl                   True        False        False       False     False      True
# http://www.almere.nl                   True        True         False       False     True       True
# http://www.alphen-chaam.nl             True        False        False       False     False      True
# http://www.alphenaandenrijn.nl         True        True         False       False     True       True
# http://www.ameland.nl                  False       False        False       False     False      False
# http://www.amersfoort.nl               True        True         False       False     True       True
# http://www.amstelveen.nl               True        False        True        False     True       True
# http://www.amsterdam.nl                True        True         True        False     False      True
# http://www.apeldoorn.nl                True        True         True        False     True       True
# http://www.appingedam.nl               False       False        False       False     False      False
# http://www.arnhem.nl                   True        True         True        False     False      True
# http://www.assen.nl                    True        False        False       True      False      True
# http://www.asten.nl                    True        True         False       False     False      True
# http://www.baarle-nassau.nl            True        False        False       False     False      True
# http://www.baarn.nl                    True        True         True        True      False      True
# http://www.barneveld.nl                True        False        False       False     False      True
# http://www.beemster.net                True        False        False       False     False      True
# http://www.beesel.nl                   True        True         True        False     True       True
# http://www.bergeijk.nl                 False       False        False       False     False      False
# http://www.bergen-nh.nl                True        True         False       False     True       True
# http://www.bergen.nl                   True        True         False       False     True       True
# http://www.bergendal.nl                True        False        False       True      False      True
# http://www.bergenopzoom.nl             True        False        False       False     True       True
# http://www.bernheze.org                True        False        False       False     False      True
# http://www.beuningen.nl                True        False        False       False     True       True
# http://www.beverwijk.nl                True        True         True        False     True       True
# http://www.bladel.nl                   False       False        False       False     False      False
# http://www.blaricum.nl                 True        False        False       False     False      True
# http://www.bloemendaal.nl              True        False        False       False     False      True
# http://www.bodegraven-reeuwijk.nl      True        False        False       False     False      True
# http://www.boekel.nl                   True        False        False       False     False      True
# http://www.borger-odoorn.nl            False       False        False       False     False      True
# http://www.borne.nl                    True        False        False       False     False      True
# http://www.borsele.nl                  True        False        False       False     False      True
# http://www.boxmeer.nl                  True        True         True        False     False      True
# http://www.boxtel.nl                   False       False        False       False     False      False
# http://www.breda.nl                    True        True         False       False     False      True
# http://www.brielle.nl                  False       False        False       False     False      False
# http://www.bronckhorst.nl              True        True         True        False     False      True
# http://www.brummen.nl                  True        True         False       False     False      True
# http://www.brunssum.nl                 False       False        False       False     False      False
# http://www.bunnik.nl                   True        False        True        False     True       True
# http://www.bunschoten.nl               True        True         False       False     False      True
# http://www.buren.nl                    True        False        False       False     False      True
# http://www.capelleaandenijssel.nl      True        True         False       False     False      True
# http://www.castricum.nl                True        True         False       False     False      True
# http://www.coevorden.nl                True        True         True        False     False      True
# http://www.cranendonck.nl              True        False        True        False     False      True
# http://www.cuijk.nl                    False       False        False       False     False      False
# http://www.culemborg.nl                False       False        False       False     False      False
# http://www.dalfsen.nl                  True        False        True        False     True       True
# http://www.dantumadiel.frl             True        False        True        False     False      True
# http://www.debilt.nl                   True        False        False       False     False      True
# http://www.defryskemarren.nl           False       True         True        False     True       True
# http://www.delft.nl                    True        True         True        False     True       True
# http://www.delfzijl.nl                 False       False        False       False     False      False
# http://www.denhaag.nl                  False       False        False       False     False      False
# http://www.denhelder.nl                True        False        False       False     True       True
# http://www.derondevenen.nl             True        False        False       False     True       True
# http://www.deurne.nl                   True        False        False       False     False      True
# http://www.deventer.nl                 True        True         False       False     True       True
# http://www.dewolden.nl                 True        False        False       False     False      True
# http://www.diemen.nl                   False       False        False       False     False      False
# http://www.dinkelland.nl               True        True         True        False     True       True
# http://www.doesburg.nl                 False       False        False       False     False      False
# http://www.doetinchem.nl               True        False        False       False     False      True
# http://www.dongen.nl                   True        False        True        False     False      True
# http://www.dordrecht.nl                True        True         True        False     False      True
# http://www.drechterland.nl             True        False        False       False     False      True
# http://www.drimmelen.nl                True        False        False       False     True       True
# http://www.dronten.nl                  True        False        False       False     False      True
# http://www.druten.nl                   True        True         False       True      False      True
# http://www.duiven.nl                   True        False        False       True      False      True
# http://www.echt-susteren.nl            True        False        True        False     True       True
# http://www.edam-volendam.nl            False       False        False       False     False      True
# http://www.ede.nl                      True        True         True        False     True       True
# http://www.eemnes.nl                   True        False        False       False     False      True
# http://www.eersel.nl                   False       False        False       False     False      False
# http://www.eijsden-margraten.nl        True        False        False       False     False      True
# http://www.eindhoven.nl                True        True         True        False     False      True
# http://www.elburg.nl                   True        True         False       False     True       True
# http://www.emmen.nl                    False       False        False       False     False      False
# http://www.enkhuizen.nl                True        False        False       False     False      True
# http://www.enschede.nl                 True        True         False       False     False      True
# http://www.epe.nl                      True        False        False       True      False      True
# http://www.ermelo.nl                   True        True         True        False     True       True
# http://www.etten-leur.nl               True        True         True        False     True       True
# http://www.geertruidenberg.nl          True        False        False       False     False      True
# http://www.gemeente-mill.nl            True        False        False       False     False      True
# http://www.gemeente-oldambt.nl         True        True         True        False     False      True
# http://www.gemeente-steenbergen.nl     True        True         False       False     True       True
# http://www.gemeentebeek.nl             False       False        False       False     False      False
# http://www.gemeenteberkelland.nl       True        True         False       True      False      True
# http://www.gemeentebest.nl             True        False        False       False     False      True
# http://www.gemeentehulst.nl            True        False        False       False     True       True
# http://www.gemeentelangedijk.nl        True        True         True        False     False      True
# http://www.gemeentemaasgouw.nl         True        True         False       False     False      True
# http://www.gemeentemaastricht.nl       True        False        True        False     False      True
# http://www.gemeentenoordenveld.nl      True        True         True        False     False      True
# http://www.gemeentesluis.nl            True        True         False       False     True       True
# http://www.gemeentestein.nl            True        True         True        False     True       True
# http://www.gemeentewesterveld.nl       False       False        False       False     True       True
# http://www.gemeentewestland.nl         False       False        False       False     False      True
# http://www.gemert-bakel.nl             True        True         False       False     True       True
# http://www.gennep.nl                   True        True         True        False     False      True
# http://www.gilzerijen.nl               True        False        False       False     True       True
# http://www.goeree-overflakkee.nl       False       True         False       False     False      True
# http://www.goes.nl                     True        False        False       True      False      True
# http://www.goirle.nl                   False       False        False       False     False      False
# http://www.gooisemeren.nl              True        False        False       False     False      True
# http://www.gorinchem.nl                True        True         False       False     False      True
# http://www.gouda.nl                    True        False        False       False     False      True
# http://www.grave.nl                    False       False        False       False     False      False
# http://www.haaksbergen.nl              True        False        False       False     False      True
# http://www.haaren.nl                   True        False        False       False     False      True
# http://www.haarlem.nl                  False       False        False       False     False      False
# http://www.halderberge.nl              True        False        False       False     False      True
# http://www.hardenberg.nl               True        True         True        False     True       True
# http://www.harderwijk.nl               True        False        False       False     False      True
# http://www.hardinxveld-giessendam.nl   True        False        False       False     False      True
# http://www.harlingen.nl                True        False        False       False     False      True
# http://www.hattem.nl                   True        True         False       False     False      True
# http://www.heemskerk.nl                True        True         False       False     False      True
# http://www.heemstede.nl                True        False        False       False     False      True
# http://www.heerde.nl                   True        False        False       False     True       True
# http://www.heerenveen.nl               False       False        False       False     False      False
# http://www.heerhugowaard.nl            True        False        False       False     False      True
# http://www.heerlen.nl                  True        True         True        True      True       True
# http://www.heeze-leende.nl             True        False        False       False     False      True
# http://www.heiloo.nl                   True        True         False       False     False      True
# http://www.hellendoorn.nl              True        True         True        False     False      True
# http://www.hellevoetsluis.nl           True        False        False       False     False      True
# http://www.helmond.nl                  True        True         True        False     True       True
# http://www.hendrik-ido-ambacht.nl      False       False        False       False     False      False
# http://www.hengelo.nl                  True        True         True        False     True       True
# http://www.heumen.nl                   True        False        False       False     False      False
# http://www.heusden.nl                  True        False        False       False     True       True
# http://www.heuvelrug.nl                True        True         True        False     True       True
# http://www.hillegom.nl                 True        False        True        False     True       True
# http://www.hilvarenbeek.nl             False       False        False       False     False      False
# http://www.hilversum.nl                True        True         True        False     True       True
# http://www.hofvantwente.nl             False       False        False       False     False      False
# http://www.hollandskroon.nl            True        True         True        False     True       True
# http://www.hoogeveen.nl                True        False        True        False     True       True
# http://www.hoorn.nl                    True        True         False       False     True       True
# http://www.houten.nl                   True        False        False       False     False      False
# http://www.huizen.nl                   True        False        False       False     True       True
# http://www.ijsselstein.nl              False       False        False       False     False      False
# http://www.kaagenbraassem.nl           True        True         False       False     True       True
# http://www.kampen.nl                   False       False        False       False     False      False
# http://www.kapelle.nl                  True        False        False       False     False      True
# http://www.katwijk.nl                  True        True         False       False     False      True
# http://www.kerkrade.nl                 True        False        False       True      False      True
# http://www.koggenland.nl               True        False        True        False     False      True
# http://www.krimpenaandenijssel.nl      True        False        False       False     False      True
# http://www.krimpenerwaard.nl           True        True         False       True      True       True
# http://www.laarbeek.nl                 True        False        False       False     False      True
# http://www.landerd.nl                  True        False        False       False     False      True
# http://www.landgraaf.nl                False       False        False       False     False      False
# http://www.landsmeer.nl                True        False        False       False     False      True
# http://www.lansingerland.nl            False       False        False       False     False      False

# %%
round(social_media_pressence.sum(axis=1)).sort_values(ascending=False)
# Out:
# parent_url
# http://www.heerlen.nl                 6
# http://www.beverwijk.nl               5
# http://www.ermelo.nl                  5
# http://www.beesel.nl                  5
# http://www.delft.nl                   5
# http://www.gemeentestein.nl           5
# http://www.apeldoorn.nl               5
# http://www.helmond.nl                 5
# http://www.hengelo.nl                 5
# http://www.heuvelrug.nl               5
# http://www.hilversum.nl               5
# http://www.baarn.nl                   5
# http://www.hollandskroon.nl           5
# http://www.etten-leur.nl              5
# http://www.hardenberg.nl              5
# http://www.ede.nl                     5
# http://www.dinkelland.nl              5
# http://www.krimpenerwaard.nl          5
# http://www.bronckhorst.nl             4
# http://www.dordrecht.nl               4
# http://www.deventer.nl                4
# http://www.bergen-nh.nl               4
# http://www.bergen.nl                  4
# http://www.dalfsen.nl                 4
# http://www.gennep.nl                  4
# http://www.gemert-bakel.nl            4
# http://www.coevorden.nl               4
# http://www.gemeentesluis.nl           4
# http://www.elburg.nl                  4
# http://www.druten.nl                  4
#                                      ..
# http://www.edam-volendam.nl           1
# http://www.borger-odoorn.nl           1
# http://www.hofvantwente.nl            0
# http://www.landgraaf.nl               0
# http://www.alblasserdam.nl            0
# http://www.appingedam.nl              0
# http://www.hendrik-ido-ambacht.nl     0
# http://www.kampen.nl                  0
# http://www.hilvarenbeek.nl            0
# http://www.ameland.nl                 0
# http://www.ijsselstein.nl             0
# http://www.delfzijl.nl                0
# http://www.heerenveen.nl              0
# http://www.bergeijk.nl                0
# http://www.diemen.nl                  0
# http://www.culemborg.nl               0
# http://www.cuijk.nl                   0
# http://www.doesburg.nl                0
# http://www.eersel.nl                  0
# http://www.brunssum.nl                0
# http://www.emmen.nl                   0
# http://www.brielle.nl                 0
# http://www.boxtel.nl                  0
# http://www.gemeentebeek.nl            0
# http://www.bladel.nl                  0
# http://www.goirle.nl                  0
# http://www.denhaag.nl                 0
# http://www.grave.nl                   0
# http://www.haarlem.nl                 0
# http://www.lansingerland.nl           0
# Length: 168, dtype: int64
